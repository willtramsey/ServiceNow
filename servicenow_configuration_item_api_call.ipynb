# %%
import requests
import json
import pandas as pd
import keyring

# %%
# defining credentials for auth
# keyring.set_password("system", "username", "password")
user = 'wramsey'
pwd = keyring.get_password("snow", "wramsey")

# %%
# Set the request parameters
url = 'https://avidxchangetest.service-now.com/api/now/table/cmdb_ci?sysparm_limit=9000'

# checking to make sure we are not querying production
if 'test' in url:
    print('Forgot to change URL!')
    url = url.replace('test', 'dev')
    print(url[:38])
# Out:
# Forgot to change URL!
# https://avidxchangedev.service-now.com

# %%
# Set proper headers
headers = {"Content-Type":"application/json","Accept":"application/json"}

# Do the HTTP request
response = requests.get(url, auth=(user, pwd), headers=headers )

# Check for HTTP codes other than 200
if response.status_code != 200: 
    print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
    exit()

# Decode the JSON response into a dictionary and use the data
data = response.json()

# %%
df_main = pd.DataFrame.from_dict(data['result'])
pd.set_option('max_columns', None)
# df_main[df_main['name'] == 'Five9' ]
df_main.head(3)
# Out:
#   attested_date skip_sync operational_status       sys_updated_on  \
# 0                   false                  1  2018-04-25 17:18:23
# 1                   false                  1  2018-05-01 14:11:57
# 2                   false                  1  2018-04-25 19:56:35
#
#   attestation_score discovery_source first_discovered sys_updated_by due_in  \
# 0                                                             CBaker
# 1                                                           TLeonard
# 2                                                          CAndersen
#
#         sys_created_on                                         sys_domain  \
# 0  2018-04-25 17:18:23  {'link': 'https://avidxchangedev.service-now.c...
# 1  2018-04-27 16:04:11  {'link': 'https://avidxchangedev.service-now.c...
# 2  2018-04-25 19:56:35  {'link': 'https://avidxchangedev.service-now.c...
#
#           install_date gl_account invoice_number sys_created_by  \
# ...

# %%
df_main[['name', 'sys_id']]
# Out:
#                       name                            sys_id
# 0           AzrDIwdevSQL01  b80cfa3fdbe11780bd3ec170ba96199b
# 1        DBA Backup Tables  b33e7820db319780bd3ec170ba9619c4
# 2     Production Netscaler  be3027b7db29d7009f9aec51ca9619dd
# 3         PRWAXTR01\AXTR01  6202dbf1dbed9f40bd3ec170ba96198f
# 4                  Unknown  8fbc3c053bc07300b924874064efc4ae
# ...                    ...                               ...
# 8995            AZDEVWVM27  5dcea162db625f005cfba895ca96194c
# 8996            AZDEVWVM28  59cea162db625f005cfba895ca961951
# 8997            AZDEVWVM29  55cea162db625f005cfba895ca961956
# 8998            AZDEVWVM30  51cea162db625f005cfba895ca96195b
# 8999            AZDEVWVM31  55cea162db625f005cfba895ca961969
#
# [9000 rows x 2 columns]

# %%
df_main.to_csv('C:\\Users\\wramsey\\Downloads\\Python\\Python\\Personal Projects\\ServiceNow Data\\config_item_pull.csv')
