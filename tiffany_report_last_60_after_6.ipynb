# %%
import requests
import json
import pandas as pd
import keyring
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# ## Bring In Data

# %%
# defining credentials for auth
# keyring.set_password("system", "username", "password")
user = 'wramsey'
pwd = 'P0#erBI'

# %%
# When all columns are pulled, these are the that are populated
# u_repeat, upon_reject, sys_updated_on, number, u_vcc, state, sys_created_by, knowledge, u_external_customer_impacted, u_ach, cmdb_ci, impact, active, priority, sys_domain_path, business_duration, u_avidpay_check, u_core, u_ipay, u_avidpay_direct, short_description, work_start, u_check, notify, sys_class_name, closed_by, parent_incident, u_choice_6, reopened_by, u_utility, reassignment_count, assigned_to, u_board, escalation, upon_approval, u_payments_delayed, made_sla, u_money_movement, child_incidents, task_effective_number, resolved_by, sys_updated_by, opened_by, sys_created_on, sys_domain, u_dollar_impact, calendar_stc, closed_at, business_service, opened_at, caller_id, reopened_time, resolved_at, u_hub, subcategory, close_code, assignment_group, u_pir_requested, business_stc, calendar_duration, close_notes, sys_id, contact_type, incident_state, urgency, severity, approval, sys_mod_count, reopen_count, location, category

# %%
# Set the request parameters - assigned to support center in last 3 months
url = 'https://avidxchange.service-now.com/api/now/table/incident?sysparm_query=assignment_group%3Dfe169ea0db5e2700bd3ec170ba961941%5Eopened_at%3Ejavascript%3Ags.beginningOfLast3Months()&sysparm_fields=u_repeat%2C%20upon_reject%2C%20sys_updated_on%2C%20number%2C%20u_vcc%2C%20state%2C%20sys_created_by%2C%20knowledge%2C%20u_external_customer_impacted%2C%20u_ach%2C%20cmdb_ci%2C%20impact%2C%20active%2C%20priority%2C%20sys_domain_path%2C%20business_duration%2C%20u_avidpay_check%2C%20u_core%2C%20u_ipay%2C%20u_avidpay_direct%2C%20short_description%2C%20work_start%2C%20u_check%2C%20notify%2C%20sys_class_name%2C%20closed_by%2C%20parent_incident%2C%20u_choice_6%2C%20reopened_by%2C%20u_utility%2C%20reassignment_count%2C%20assigned_to%2C%20u_board%2C%20escalation%2C%20upon_approval%2C%20u_payments_delayed%2C%20made_sla%2C%20u_money_movement%2C%20child_incidents%2C%20task_effective_number%2C%20resolved_by%2C%20sys_updated_by%2C%20opened_by%2C%20sys_created_on%2C%20sys_domain%2C%20u_dollar_impact%2C%20calendar_stc%2C%20closed_at%2C%20business_service%2C%20opened_at%2C%20caller_id%2C%20reopened_time%2C%20resolved_at%2C%20u_hub%2C%20subcategory%2C%20close_code%2C%20assignment_group%2C%20u_pir_requested%2C%20business_stc%2C%20calendar_duration%2C%20close_notes%2C%20sys_id%2C%20contact_type%2C%20incident_state%2C%20urgency%2C%20severity%2C%20approval%2C%20sys_mod_count%2C%20reopen_count%2C%20location%2C%20category&sysparm_limit=3500'

# %%
# Set proper headers
headers = {"Content-Type":"application/json","Accept":"application/json"}

# Do the HTTP request
response = requests.get(url, auth=(user, pwd), headers=headers )

# Check for HTTP codes other than 200
if response.status_code != 200:
    print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
    print('Status:', response.status_code, '\n')
    print('Headers:', response.headers, '\n')
    data = response.json()
    print(json.dumps(data, indent=2))

# %%
# Decode the JSON response into a dictionary and use the data
data = response.json()

# %%
# DO NOT RUN THIS ON LARGE FILES!!! It just makes JSON pretty
# string = json.dumps(data, indent=2)
# print(string)

# %%
# this turns the dictionary into a pandas df
df_main = pd.DataFrame.from_dict(data['result'])
pd.set_option('max_columns', None)
df_main.tail(1)
# Out:
#      u_repeat made_sla upon_reject u_money_movement       sys_updated_on  \
# 2297    false     true      cancel            false  2021-02-24 14:00:02
#
#      child_incidents task_effective_number      number  u_vcc  \
# 2297               0            INC0063644  INC0063644  false
#
#                                             resolved_by sys_updated_by  \
# 2297  {'link': 'https://avidxchange.service-now.com/...         system
#
#                                               opened_by       sys_created_on  \
# 2297  {'link': 'https://avidxchange.service-now.com/...  2021-02-17 03:48:27
#
#                                              sys_domain u_dollar_impact state  \
# 2297  {'link': 'https://avidxchange.service-now.com/...               0     7
#
#      sys_created_by knowledge u_external_customer_impacted  u_ach  \
# 2297         DWalsh     false                        false  false
#
#      calendar_stc            closed_at  \
# 2297        36326  2021-02-24 14:00:02
#
#                                                 cmdb_ci impact active  \
# 2297  {'link': 'https://avidxchange.service-now.com/...      3  false
#
#                                        business_service priority  \
# 2297  {'link': 'https://avidxchange.service-now.com/...        4
#
#      sys_domain_path            opened_at    business_duration  \
# 2297               /  2021-02-17 03:48:27  1970-01-01 01:53:53
#
#                                               caller_id reopened_time  \
# 2297  {'link': 'https://avidxchange.service-now.com/...
#
#               resolved_at  u_hub u_avidpay_check u_core u_ipay  \
# 2297  2021-02-17 13:53:53  false           false  false  false
#
#                subcategory u_avidpay_direct  \
# 2297  Microsoft PowerPoint            false
#
#                                       short_description           work_start  \
# 2297  My PowerPoint files are trying to open or down...  2021-02-17 03:48:28
#
#                 close_code                                   assignment_group  \
# 2297  Solved (Permanently)  {'link': 'https://avidxchange.service-now.com/...
#
#      u_pir_requested u_check business_stc    calendar_duration notify  \
# 2297           false   false         6833  1970-01-08 10:11:35      1
#
#      sys_class_name                                        close_notes  \
# 2297       incident  Repaired office, re-associated app types, reso...
#
#                                               closed_by parent_incident  \
# 2297  {'link': 'https://avidxchange.service-now.com/...
#
#      u_choice_6                            sys_id  contact_type reopened_by  \
# 2297          1  fffd0bbedbda28109f9aec51ca961937  Self Service
#
#      incident_state urgency u_utility reassignment_count  \
# 2297              7       2     false                  0
#
#                                             assigned_to severity  \
# 2297  {'link': 'https://avidxchange.service-now.com/...        3
#
#            approval sys_mod_count reopen_count u_board escalation  \
# 2297  not requested             5            0   false          0
#
#      upon_approval u_payments_delayed  \
# 2297       proceed              false
#
#                                                location  category
# 2297  {'link': 'https://avidxchange.service-now.com/...  software

# %%
# Number of rows and columns
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])
# Out:
# Number of Rows:  2298
# Number of Columns:  71

# %% [markdown]
# ## Extract Dictionaries

# %% [markdown]
# ### Resolved_By Dictionary

# %%
# here we are taking the column "resolved_by" and converting it into 3 columns
df_resolved_by = df_main.resolved_by.apply(pd.Series)

# now rename columns to make easier
df_resolved_by['resolved_by_username_value'] = df_resolved_by['value']

# So now, in anticipation of appending the new "username_value" created above to the main df, we need to make sure the 
# number of rows are the same in each (so the concatenation matches up)
print('Before concatenation: df_main')
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])
print('\n')

print('df_resolved_by')
print('Number of Rows: ', df_resolved_by.shape[0])
print('Number of Columns: ', df_resolved_by.shape[1])
print('\n')

# here, we are concatenating the newly made series to the 'main' df
df = pd.concat([df_main, df_resolved_by['resolved_by_username_value']],axis=1)


try:
    if df_main['resolved_by_username_value'] is None:
        pass
except:
    df_main = pd.concat([df_main, df_resolved_by['resolved_by_username_value']],axis=1)


print('After concatenation: df_main')
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])

df.head(1)
# Out:
# Before concatenation: df_main
# Number of Rows:  2298
# Number of Columns:  71
#
#
# df_resolved_by
# Number of Rows:  2298
# Number of Columns:  4
#
#
# After concatenation: df_main
# Number of Rows:  2298
# Number of Columns:  72
#   u_repeat made_sla upon_reject u_money_movement       sys_updated_on  \
# 0    false     true      cancel            false  2021-03-19 15:00:01
#
#   child_incidents task_effective_number      number  u_vcc  \
# 0               0            INC0066309  INC0066309  false
#
#                                          resolved_by sys_updated_by  \
# 0  {'link': 'https://avidxchange.service-now.com/...         system
#
#                                            opened_by       sys_created_on  \
# 0  {'link': 'https://avidxchange.service-now.com/...  2021-03-11 13:05:17
#
#                                           sys_domain u_dollar_impact state  \
# 0  {'link': 'https://avidxchange.service-now.com/...               0     7
#
#   sys_created_by knowledge u_external_customer_impacted  u_ach calendar_stc  \
# 0      aoshields     false                        false  false         7067
#
#              closed_at                                            cmdb_ci  \
# 0  2021-03-19 15:00:01  {'link': 'https://avidxchange.service-now.com/...
#
#   impact active                                   business_service priority  \
# 0      3  false  {'link': 'https://avidxchange.service-now.com/...        3
#
#   sys_domain_path            opened_at    business_duration  \
# 0               /  2021-03-11 13:05:16  1970-01-01 01:57:47
#
#                                            caller_id reopened_time  \
# 0  {'link': 'https://avidxchange.service-now.com/...
#
#            resolved_at  u_hub u_avidpay_check u_core u_ipay  \
# 0  2021-03-11 15:03:03  false           false  false  false
#
#                  subcategory u_avidpay_direct              short_description  \
# 0  Salesforce (Org1 - Sales)            false  Can not log in to salesforce.
#
#   work_start                 close_code  \
# 0             Closed/Resolved by Caller
#
#                                     assignment_group u_pir_requested u_check  \
# 0  {'link': 'https://avidxchange.service-now.com/...           false   false
#
#   business_stc    calendar_duration notify sys_class_name  \
# 0         7067  1970-01-09 01:54:45      1       incident
#
#                                          close_notes  \
# 0  Resolution Notes (Sent to Customer) copied fro...
#
#                                            closed_by  \
# 0  {'link': 'https://avidxchange.service-now.com/...
#
#                                      parent_incident u_choice_6  \
# 0  {'link': 'https://avidxchange.service-now.com/...          1
#
#                              sys_id  contact_type reopened_by incident_state  \
# 0  0001228adbb660d09f9aec51ca961920  Self Service                          7
#
#   urgency u_utility reassignment_count  \
# 0       1     false                  0
#
#                                          assigned_to severity       approval  \
# 0  {'link': 'https://avidxchange.service-now.com/...        3  not requested
#
#   sys_mod_count reopen_count u_board escalation upon_approval  \
# 0            16            0   false          0       proceed
#
#   u_payments_delayed                                           location  \
# 0              false  {'link': 'https://avidxchange.service-now.com/...
#
#    category        resolved_by_username_value
# 0  software  34cb2daddb582600a7895e09af961971

# %% [markdown]
# ### Unpacking the rest of the dictionaries

# %%
# Ok, so now let's unpack the other dictionaries into new series, and add them to main df
# adding try/except blocks here so that the code is idempotent (because I 'run all' a lot)

try:
    if df_main['opened_by_value'] is None:
        pass
except:
    df_opened_by = df_main.opened_by.apply(pd.Series)
    df_opened_by['opened_by_value'] = df_opened_by['value']
    df_main = pd.concat([df_main, df_opened_by['opened_by_value']],axis=1)


try:
    if df_main['sys_domain_value'] is None:
        pass
except:    
    df_sys_domain = df_main.sys_domain.apply(pd.Series)
    df_sys_domain['sys_domain_value'] = df_sys_domain['value']
    df_main = pd.concat([df_main, df_sys_domain['sys_domain_value']],axis=1)


try:
    if df_main['configuration_item_value'] is None:
        pass
except:      
    df_cmdb_ci = df_main.cmdb_ci.apply(pd.Series)
    df_cmdb_ci['configuration_item_value'] = df_cmdb_ci['value']
    df_main = pd.concat([df_main, df_cmdb_ci['configuration_item_value']],axis=1)

    
try:
    if df_main['caller_id_value'] is None:
        pass
except:  
    df_caller_id = df_main.caller_id.apply(pd.Series)
    df_caller_id['caller_id_value'] = df_caller_id['value']
    df_main = pd.concat([df_main, df_caller_id['caller_id_value']],axis=1)

    
try:
    if df_main['assignment_group_value'] is None:
        pass
except:  
    df_assignment_group = df_main.assignment_group.apply(pd.Series)
    df_assignment_group['assignment_group_value'] = df_assignment_group['value']
    df_main = pd.concat([df_main, df_assignment_group['assignment_group_value']],axis=1)

    
try:
    if df_main['closed_by_value'] is None:
        pass
except:    
    df_closed_by = df_main.closed_by.apply(pd.Series)
    df_closed_by['closed_by_value'] = df_closed_by['value']
    df_main = pd.concat([df_main, df_closed_by['closed_by_value']],axis=1)

    
try:
    if df_main['parent_incident_value'] is None:
        pass
except: 
    df_parent_incident = df_main.parent_incident.apply(pd.Series)
    df_parent_incident['parent_incident_value'] = df_parent_incident['value']
    df_main = pd.concat([df_main, df_parent_incident['parent_incident_value']],axis=1)

    
try:
    if df_main['assigned_to_value'] is None:
        pass
except: 
    df_assigned_to = df_main.assigned_to.apply(pd.Series)
    df_assigned_to['assigned_to_value'] = df_assigned_to['value']
    df_main = pd.concat([df_main, df_assigned_to['assigned_to_value']],axis=1)

    
try:
    if df_main['location_value'] is None:
        pass
except: 
    df_location = df_main.location.apply(pd.Series)
    df_location['location_value'] = df_location['value']
    df_main = pd.concat([df_main, df_location['location_value']],axis=1)

    
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])
df_main.head(1)
# Out:
# Number of Rows:  2298
# Number of Columns:  81
#   u_repeat made_sla upon_reject u_money_movement       sys_updated_on  \
# 0    false     true      cancel            false  2021-03-19 15:00:01
#
#   child_incidents task_effective_number      number  u_vcc  \
# 0               0            INC0066309  INC0066309  false
#
#                                          resolved_by sys_updated_by  \
# 0  {'link': 'https://avidxchange.service-now.com/...         system
#
#                                            opened_by       sys_created_on  \
# 0  {'link': 'https://avidxchange.service-now.com/...  2021-03-11 13:05:17
#
#                                           sys_domain u_dollar_impact state  \
# 0  {'link': 'https://avidxchange.service-now.com/...               0     7
#
#   sys_created_by knowledge u_external_customer_impacted  u_ach calendar_stc  \
# 0      aoshields     false                        false  false         7067
#
#              closed_at                                            cmdb_ci  \
# 0  2021-03-19 15:00:01  {'link': 'https://avidxchange.service-now.com/...
#
#   impact active                                   business_service priority  \
# 0      3  false  {'link': 'https://avidxchange.service-now.com/...        3
#
#   sys_domain_path            opened_at    business_duration  \
# 0               /  2021-03-11 13:05:16  1970-01-01 01:57:47
#
#                                            caller_id reopened_time  \
# 0  {'link': 'https://avidxchange.service-now.com/...
#
#            resolved_at  u_hub u_avidpay_check u_core u_ipay  \
# 0  2021-03-11 15:03:03  false           false  false  false
#
#                  subcategory u_avidpay_direct              short_description  \
# 0  Salesforce (Org1 - Sales)            false  Can not log in to salesforce.
#
#   work_start                 close_code  \
# 0             Closed/Resolved by Caller
#
#                                     assignment_group u_pir_requested u_check  \
# 0  {'link': 'https://avidxchange.service-now.com/...           false   false
#
#   business_stc    calendar_duration notify sys_class_name  \
# 0         7067  1970-01-09 01:54:45      1       incident
#
#                                          close_notes  \
# 0  Resolution Notes (Sent to Customer) copied fro...
#
#                                            closed_by  \
# 0  {'link': 'https://avidxchange.service-now.com/...
#
#                                      parent_incident u_choice_6  \
# 0  {'link': 'https://avidxchange.service-now.com/...          1
#
#                              sys_id  contact_type reopened_by incident_state  \
# 0  0001228adbb660d09f9aec51ca961920  Self Service                          7
#
#   urgency u_utility reassignment_count  \
# 0       1     false                  0
#
#                                          assigned_to severity       approval  \
# 0  {'link': 'https://avidxchange.service-now.com/...        3  not requested
#
#   sys_mod_count reopen_count u_board escalation upon_approval  \
# 0            16            0   false          0       proceed
#
#   u_payments_delayed                                           location  \
# 0              false  {'link': 'https://avidxchange.service-now.com/...
#
#    category        resolved_by_username_value  \
# 0  software  34cb2daddb582600a7895e09af961971
#
#                     opened_by_value sys_domain_value  \
# 0  a78bbd40dbcee0149f9aec51ca961986           global
#
#            configuration_item_value                   caller_id_value  \
# 0  b1b9171cdbecee000f9f52e9af9619fa  a78bbd40dbcee0149f9aec51ca961986
#
#              assignment_group_value                   closed_by_value  \
# 0  fe169ea0db5e2700bd3ec170ba961941  34cb2daddb582600a7895e09af961971
#
#               parent_incident_value                 assigned_to_value  \
# 0  8c31060edb7260d09f9aec51ca96199b  9b75d6dcdb744340094bf209af961919
#
#                      location_value
# 0  5d43995edbe69b0020acde82ca961994

# %% [markdown]
# ### Busines Service Dictionary - Different Method

# %%
# a different method, same result
# getting a list of all values in the "value" key for named series-dictionary
assignment = [d.get('value') for d in df_main.assignment_group]

# then turning that list into series with column name
test2 = pd.Series(assignment, name = 'business_service_value')

# then a concat with main df
df_main = pd.concat([df_main, test2], axis=1)

# %%
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])
# Out:
# Number of Rows:  2298
# Number of Columns:  82

# %% [markdown]
# ### Drop all uneccessary columns

# %%
# pass a list of columns to be removed
json_columns = ['resolved_by', 'opened_by', 'sys_domain', 'cmdb_ci', 'business_service', 'caller_id', 'assignment_group',
                'closed_by', 'assigned_to', 'location']

try:
    for item in json_columns:
        df_main = df_main.drop([item], axis=1)
except:
    pass

# %%
print('Number of Rows: ', df_main.shape[0])
print('Number of Columns: ', df_main.shape[1])
df_main.head(1)
# Out:
# Number of Rows:  2298
# Number of Columns:  72
#   u_repeat made_sla upon_reject u_money_movement       sys_updated_on  \
# 0    false     true      cancel            false  2021-03-19 15:00:01
#
#   child_incidents task_effective_number      number  u_vcc sys_updated_by  \
# 0               0            INC0066309  INC0066309  false         system
#
#         sys_created_on u_dollar_impact state sys_created_by knowledge  \
# 0  2021-03-11 13:05:17               0     7      aoshields     false
#
#   u_external_customer_impacted  u_ach calendar_stc            closed_at  \
# 0                        false  false         7067  2021-03-19 15:00:01
#
#   impact active priority sys_domain_path            opened_at  \
# 0      3  false        3               /  2021-03-11 13:05:16
#
#      business_duration reopened_time          resolved_at  u_hub  \
# 0  1970-01-01 01:57:47                2021-03-11 15:03:03  false
#
#   u_avidpay_check u_core u_ipay                subcategory u_avidpay_direct  \
# 0           false  false  false  Salesforce (Org1 - Sales)            false
#
#                short_description work_start                 close_code  \
# 0  Can not log in to salesforce.             Closed/Resolved by Caller
#
#   u_pir_requested u_check business_stc    calendar_duration notify  \
# 0           false   false         7067  1970-01-09 01:54:45      1
#
#   sys_class_name                                        close_notes  \
# 0       incident  Resolution Notes (Sent to Customer) copied fro...
#
#                                      parent_incident u_choice_6  \
# 0  {'link': 'https://avidxchange.service-now.com/...          1
#
#                              sys_id  contact_type reopened_by incident_state  \
# 0  0001228adbb660d09f9aec51ca961920  Self Service                          7
#
#   urgency u_utility reassignment_count severity       approval sys_mod_count  \
# 0       1     false                  0        3  not requested            16
#
#   reopen_count u_board escalation upon_approval u_payments_delayed  category  \
# 0            0   false          0       proceed              false  software
#
#          resolved_by_username_value                   opened_by_value  \
# 0  34cb2daddb582600a7895e09af961971  a78bbd40dbcee0149f9aec51ca961986
#
#   sys_domain_value          configuration_item_value  \
# 0           global  b1b9171cdbecee000f9f52e9af9619fa
#
#                     caller_id_value            assignment_group_value  \
# 0  a78bbd40dbcee0149f9aec51ca961986  fe169ea0db5e2700bd3ec170ba961941
#
#                     closed_by_value             parent_incident_value  \
# 0  34cb2daddb582600a7895e09af961971  8c31060edb7260d09f9aec51ca96199b
#
#                   assigned_to_value                    location_value  \
# 0  9b75d6dcdb744340094bf209af961919  5d43995edbe69b0020acde82ca961994
#
#              business_service_value
# 0  fe169ea0db5e2700bd3ec170ba961941

# %% [markdown]
# ## Transform Datatypes

# %%
# Replace id_values with real names
df_main = df_main.replace(['544c7f15dba5f3005cfba895ca961999','bfc51bbedb7054105cfba895ca9619f2', '0a66f38adb640f00094bf209af9619de',
                 '4f53dc9cdb9300505cfba895ca9619fc', 'd811dfb6db7054105cfba895ca96190f', '9b75d6dcdb744340094bf209af961919',
                 '125e5bcedbbde200094bf209af9619fd', 'ffc51bbedb7054105cfba895ca9619dd'],
                ['Shawn McCoy','Taylor Ramsey', 'Jacob Webb', 'Lynda Fang', 'Diana Sayvongsa', 'Tiffany Leonard',
                 'Scott Bruce', 'Valentin Correa'])

# %%
df_main.head(1)
# Out:
#   u_repeat made_sla upon_reject u_money_movement       sys_updated_on  \
# 0    false     true      cancel            false  2021-03-19 15:00:01
#
#   child_incidents task_effective_number      number  u_vcc sys_updated_by  \
# 0               0            INC0066309  INC0066309  false         system
#
#         sys_created_on u_dollar_impact state sys_created_by knowledge  \
# 0  2021-03-11 13:05:17               0     7      aoshields     false
#
#   u_external_customer_impacted  u_ach calendar_stc            closed_at  \
# 0                        false  false         7067  2021-03-19 15:00:01
#
#   impact active priority sys_domain_path            opened_at  \
# 0      3  false        3               /  2021-03-11 13:05:16
#
#      business_duration reopened_time          resolved_at  u_hub  \
# 0  1970-01-01 01:57:47                2021-03-11 15:03:03  false
#
#   u_avidpay_check u_core u_ipay                subcategory u_avidpay_direct  \
# 0           false  false  false  Salesforce (Org1 - Sales)            false
#
#                short_description work_start                 close_code  \
# 0  Can not log in to salesforce.             Closed/Resolved by Caller
#
#   u_pir_requested u_check business_stc    calendar_duration notify  \
# 0           false   false         7067  1970-01-09 01:54:45      1
#
#   sys_class_name                                        close_notes  \
# 0       incident  Resolution Notes (Sent to Customer) copied fro...
#
#                                      parent_incident u_choice_6  \
# 0  {'link': 'https://avidxchange.service-now.com/...          1
#
#                              sys_id  contact_type reopened_by incident_state  \
# 0  0001228adbb660d09f9aec51ca961920  Self Service                          7
#
#   urgency u_utility reassignment_count severity       approval sys_mod_count  \
# 0       1     false                  0        3  not requested            16
#
#   reopen_count u_board escalation upon_approval u_payments_delayed  category  \
# 0            0   false          0       proceed              false  software
#
#          resolved_by_username_value                   opened_by_value  \
# 0  34cb2daddb582600a7895e09af961971  a78bbd40dbcee0149f9aec51ca961986
#
#   sys_domain_value          configuration_item_value  \
# 0           global  b1b9171cdbecee000f9f52e9af9619fa
#
#                     caller_id_value            assignment_group_value  \
# 0  a78bbd40dbcee0149f9aec51ca961986  fe169ea0db5e2700bd3ec170ba961941
#
#                     closed_by_value             parent_incident_value  \
# 0  34cb2daddb582600a7895e09af961971  8c31060edb7260d09f9aec51ca96199b
#
#   assigned_to_value                    location_value  \
# 0   Tiffany Leonard  5d43995edbe69b0020acde82ca961994
#
#              business_service_value
# 0  fe169ea0db5e2700bd3ec170ba961941

# %%
# what columns/datatypes are we working with?
time_columns = ['sys_updated_on', 'sys_created_on', 'closed_at', 'opened_at', 'business_duration', 'reopened_time', 'resolved_at', 'work_start', 'calendar_duration']
df_main[time_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2298 entries, 0 to 2297
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sys_updated_on     2298 non-null   object
#  1   sys_created_on     2298 non-null   object
#  2   closed_at          2298 non-null   object
#  3   opened_at          2298 non-null   object
#  4   business_duration  2298 non-null   object
#  5   reopened_time      2298 non-null   object
#  6   resolved_at        2298 non-null   object
#  7   work_start         2298 non-null   object
#  8   calendar_duration  2298 non-null   object
# dtypes: object(9)
# memory usage: 161.7+ KB

# %%
# Change datatypes of all time-based columns
time_columns = ['sys_updated_on', 'sys_created_on', 'closed_at', 'opened_at', 'business_duration', 'reopened_time',
                'resolved_at', 'work_start', 'calendar_duration']

for item in time_columns:
    df_main[item] = pd.to_datetime(df_main[item])

# # Create additional time columns
# df_main['opened_at'] = df_main['opened_at'] - timedelta(hours=5)
# df_main['resolved_at'] = df_main['resolved_at'] - timedelta(hours=5)
# df_main['opened_at_hour'] = df_main['opened_at'].dt.hour
# df_main['opened_at_month'] = df_main['opened_at'].dt.month
# df_main['opened_at_day'] = df_main['opened_at'].dt.day
# df_main['opened_at_day_of_year'] = df_main['opened_at'].dt.dayofyear
# df_main['opened_at_clone'] = df_main['opened_at']
# df_main['resolution_time_length'] = df_main.resolved_at - df_main.opened_at
# df_main['resolution_time_total_hours'] = df_main['resolution_time_length'].dt.total_seconds()/3600
# print(type(df_main['opened_at_clone'].iloc[0]))
# df_main[['opened_at', 'task_effective_number', 'opened_at_hour', 'opened_at_month', 'opened_at_day', 'opened_at_day_of_year',
#          'opened_at_clone', 'resolution_time_length', 'resolution_time_total_hours']].head(5).sort_values('opened_at_day').head(2)

# %%
df_main['opened_at'].sort_values().tail()
# Out:
# 86     2021-04-26 19:36:13
# 439    2021-04-26 19:37:15
# 551    2021-04-26 19:43:42
# 1589   2021-04-26 21:15:08
# 2112   2021-04-26 21:24:57
# Name: opened_at, dtype: datetime64[ns]

# %% [markdown]
# ## File output

# %%
# df_main.to_csv('C:\\Users\\wramsey\\Downloads\\Python\\Python\\Personal Projects\\ServiceNow Data\snow33.csv', index=False)
df_main.to_csv('C:\\Users\\wramsey\\Desktop\\tiffany.csv', index=False)
